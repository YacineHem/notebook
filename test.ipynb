# %%
15*45
# Out:
# 675

# %%
from fasteda import fast_eda
import pandas as pd


df = pd.read_csv("train.csv")
fast_eda(df, target = "Survived")
# Out:
# DataFrame Head:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# DataFrame Tail:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# ...

# %%
import pandas as pd
import matplotlib as plt
dt=pd.read_csv("Best Movies Netflix.csv")
sort= dt.sort_values(by=['NUMBER_OF_VOTES'], ascending=False)
sort = sort.groupby('MAIN_GENRE').plot(legend=True)
print(sort.head())
# Out:
# MAIN_GENRE
# action         AxesSubplot(0.08,0.07;0.87x0.81)
# animation      AxesSubplot(0.08,0.07;0.87x0.81)
# comedy         AxesSubplot(0.08,0.07;0.87x0.81)
# crime          AxesSubplot(0.08,0.07;0.87x0.81)
# documentary    AxesSubplot(0.08,0.07;0.87x0.81)
# dtype: object

# %%
from statistics import mean 
import pandas as pd
import matplotlib.pyplot as plt

dt=pd.read_csv("Best Movies Netflix.csv")
x= dt.NUMBER_OF_VOTES
y= dt.MAIN_GENRE
sort= dt.sort_values(by=['NUMBER_OF_VOTES'], ascending=False)

plt.scatter(x, y)

plt.xlabel("Nombres de votes (en million)")
plt.ylabel("Genre du Film")

plt.show()

# %%
from statistics import mean 
import pandas as pd
import matplotlib.pyplot as plt

dt=pd.read_csv("Best Movies Netflix.csv")
pargenre=dt[['MAIN_GENRE','NUMBER_OF_VOTES']]
dt=pargenre.groupby(['MAIN_GENRE']).mean()
sort= dt.sort_values(by=['NUMBER_OF_VOTES'], ascending=False)
sort
# Out:
#              NUMBER_OF_VOTES
# MAIN_GENRE
# scifi          547524.428571
# western        395729.857143
# horror         219894.250000
# crime          183700.476190
# drama          144401.086093
# thriller       142346.915254
# fantasy        138945.157895
# animation      113837.666667
# action         107037.800000
# comedy          81099.862069
# romance         68028.095238
# war             47227.333333
# documentary     25214.850000
# musical         23559.000000
# sports          21558.000000

# %%
from statistics import mean 
import pandas as pd
import matplotlib.pyplot as plt

dt=pd.read_csv("Best Movies Netflix.csv")
pargenre=dt[['MAIN_GENRE','NUMBER_OF_VOTES']]
sort= pargenre.sort_values(by=['NUMBER_OF_VOTES'], ascending=False)
sort=sort.groupby(['MAIN_GENRE']).mean()
vote=sort.NUMBER_OF_VOTES
genre=["action","animation","comedy","crime","documentary",
       "drama","fantasy","horror","musical","romance","scifi","sports","thriller","war","western"]
plt.scatter(vote,genre)
